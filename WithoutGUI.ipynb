# %%
from experta import *
import random

# %%
class Car(KnowledgeEngine):
    @DefFacts()
    def init(self):
        print("Welcom To Our System")
        yield Fact(action='car')
        
        
    ####################################################################
    
    ### CAR mainfacture ##############################
        
        
    @Rule(NOT(Fact(m1=W())))
    def main1(self):
         self.declare(Fact(m1=input("Do You Want Japan Car? ")))
            
        
    @Rule(NOT(Fact(m2=W())))
    def main2(self):
         self.declare(Fact(m2=input("Do You Want France Car? ")))
            
        
    @Rule(NOT(Fact(m3=W())))
    def main3(self):
         self.declare(Fact(m3=input("Do You Want Germany Car? ")))
            
        
    @Rule(NOT(Fact(m4=W())))
    def main4(self):
         self.declare(Fact(m4=input("Do You Want USA Car? ")))
            
            
    #########################################################################
    
    @Rule(NOT(Fact(t1=W())))
    def type1(self):
         self.declare(Fact(t1=input("Do You Want Commercial Car? ")))
            
    @Rule(NOT(Fact(t2=W())))
    def type2(self):
         self.declare(Fact(t2=input("Do You Want Popular Car? ")))
            
    @Rule(NOT(Fact(t3=W())))
    def type3(self):
         self.declare(Fact(t3=input("Do You Want Modern Car? ")))
            
    @Rule(NOT(Fact(t4=W())))
    def type4(self):
         self.declare(Fact(t4=input("Do You Want Sport Car? ")))
            
        
    ############################################################################
    
    @Rule(NOT(Fact(f1=W())))
    def fuel1(self):
         self.declare(Fact(f1=input("Do You Want Mazout Car? ")))
            
    @Rule(NOT(Fact(f2=W())))
    def fuel2(self):
         self.declare(Fact(f2=input("Do You Want Electric Car? ")))
            
    @Rule(NOT(Fact(f3=W())))
    def fuel3(self):
         self.declare(Fact(f3=input("Do You Want Petrol Car? ")))
            
            
    ############################################################################
    
    
    @Rule(NOT(Fact(p1=W())))
    def price1(self):
         self.declare(Fact(p1=input("Do You Want Price of The Car Bewteen 30-70 Thaousand Pounds? ")))

    
    @Rule(NOT(Fact(p2=W())))
    def price2(self):
         self.declare(Fact(p2=input("Do You Want Price of The Car Bewteen 70-180 Thaousand Pounds? ")))
            
    
    @Rule(NOT(Fact(p3=W())))
    def price3(self):
         self.declare(Fact(p3=input("Do You Want Price of The Car Bewteen 180-600 Thaousand Pounds? ")))
            
            
    ################################################################################
    
        
    
    @Rule(Fact(m1="yes"), Fact(t2="yes") , Fact(f3="yes") ,Fact(p1="yes"))
    def car1(self):
        self.declare(Fact(CarType="Cherry Tiggo 2"))
        
    @Rule(Fact(m1="yes"), Fact(t4="yes") , Fact(f2="yes") ,Fact(p3="yes"))
    def car11(self):
        self.declare(Fact(CarType="Toyota Hilux"))   
        
        
    ################################################################################
    
    @Rule(Fact(m2="yes"), Fact(t2="yes") , Fact(f1="yes") ,Fact(p2="yes"))
    def car2(self):
        self.declare(Fact(CarType="Peugot E-208")) 
        
    @Rule(Fact(m2="yes"), Fact(t1="yes") , Fact(f1="yes") ,Fact(p3="yes"))
    def car22(self):
        self.declare(Fact(CarType="Citroën C4 Cactus")) 
        
        
    ################################################################################

    @Rule(Fact(m3="yes"), Fact(t2="yes") , Fact(f1="yes") ,Fact(p2="yes"))
    def car3(self):
        self.declare(Fact(CarType="Mercides Class A")) 
        
    @Rule(Fact(m3="yes"), Fact(t1="yes") , Fact(f1="yes") ,Fact(p3="yes"))
    def car33(self):
        self.declare(Fact(CarType="Mercides Class S")) 
        
    @Rule(Fact(m3="yes"), Fact(t2="yes") , Fact(f3="yes") ,Fact(p1="yes"))
    def car333(self):
        self.declare(Fact(CarType="Audi A4")) 
    
    ################################################################################

    @Rule(Fact(m4="yes"), Fact(t1="yes") , Fact(f2="yes") ,Fact(p3="yes"))
    def car4(self):
        self.declare(Fact(CarType="Tesla model 3")) 
        
    ################################################################################
    
    @Rule(Fact(CarType=MATCH.CarType))
    def cars(self, CarType):
        print("\n The Most Probable Car That You Need  Is:  %s\n" %(CarType))
   

    #@Rule(NOT(Fact(car=MATCH.car)))
    #def not_bestCar(self):
    #    carName= random.choice(["Ford F_150 ","Toyota prado"])
    #    print("\n There Is No Match So We Recoomend You: " + carName + "\n")
    
        #This Function Is Run If The Result Doesn't Match Any Rule. 
        
    ##################################################################################
engine = Car()
#while(1):
engine.reset()  
engine.run() 
    #print("Would you like to find some other cars?")
    #if input() == "no":
     #   break;
# Out:
# Welcom To Our System
# Do You Want Mazout Car? yes
# Do You Want Electric Car? no
# Do You Want Popular Car? no
# Do You Want Commercial Car? yes
# Do You Want Modern Car? no
# Do You Want Petrol Car? no
# Do You Want Sport Car? no
# Do You Want Japan Car? no
# Do You Want USA Car? no
# Do You Want Price of The Car Bewteen 180-600 Thaousand Pounds? yes
# Do You Want Germany Car? yes
#
#  The Most Probable Car That You Need  Is:  Mercides Class S
